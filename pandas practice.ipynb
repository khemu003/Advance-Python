# %%
import pandas as pd

# %%
df = pd.read_csv("placement.csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
top_left_corner_df = df.iloc[:4, :2]
top_left_corner_df
# Out:
#    cgpa  resume_score
# 0  8.14          6.52
# 1  6.17          5.17
# 2  8.27          8.86
# 3  6.88          7.27

# %%
df.loc[0:3, ["cgpa", "resume_score"]]
# Out:
#    cgpa  resume_score
# 0  8.14          6.52
# 1  6.17          5.17
# 2  8.27          8.86
# 3  6.88          7.27

# %%
# check the range index and columns name
df.axes
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
# for the check type of columns
df.dtypes
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
# it return True if there is any missing(NULL) data in dataframe otherwise False
df.empty
# Out:
# False

# %%
# find the missing value(NULL), it return True if there is any missing(NULL) data in dataframe otherwise False
df.isnull()
# Out:
#      cgpa  resume_score  placed
# 0   False         False   False
# 1   False         False   False
# 2   False         False   False
# 3   False         False   False
# 4   False         False   False
# ..    ...           ...     ...
# 95  False         False   False
# 96  False         False   False
# 97  False         False   False
# 98  False         False   False
# 99  False         False   False
#
# [100 rows x 3 columns]

# %%
# find the total sum of missing value
df.isnull().sum()
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
# For drop the missing value row
df.dropna()
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (100, 3)

# %%
df.size
# Out:
# 300

# %%
df.values
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df_copy = df.copy()
df_copy
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
sorted_df = df.sort_values(by = "resume_score")
sorted_df
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
df["new_cgpa"] = df["cgpa"].astype(int)
df
# Out:
#     cgpa  resume_score  placed  new_cgpa
# 0   8.14          6.52       1         8
# 1   6.17          5.17       0         6
# 2   8.27          8.86       1         8
# 3   6.88          7.27       1         6
# 4   7.52          7.30       1         7
# ..   ...           ...     ...       ...
# 95  6.33          6.38       0         6
# 96  8.23          7.76       1         8
# 97  6.65          7.78       0         6
# 98  8.14          5.63       1         8
# 99  6.09          6.61       0         6
#
# [100 rows x 4 columns]

# %%
df = df.drop(columns = ["new_cgpa"])
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
new_df = df

# %%
new_df["cgpa"] = new_df["cgpa"].astype(int)
new_df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
copy_df = df.copy()
copy_df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
copy_df["cgpa"] = copy_df["cgpa"].astype(float)
copy_df
# Out:
#     cgpa  resume_score  placed
# 0    8.0          6.52       1
# 1    6.0          5.17       0
# 2    8.0          8.86       1
# 3    6.0          7.27       1
# 4    7.0          7.30       1
# ..   ...           ...     ...
# 95   6.0          6.38       0
# 96   8.0          7.76       1
# 97   6.0          7.78       0
# 98   8.0          5.63       1
# 99   6.0          6.61       0
#
# [100 rows x 3 columns]

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
df["cgpa"] = df["cgpa"].add(4)
df
# Out:
#     cgpa  resume_score  placed
# 0     12          6.52       1
# 1     10          5.17       0
# 2     12          8.86       1
# 3     10          7.27       1
# 4     11          7.30       1
# ..   ...           ...     ...
# 95    10          6.38       0
# 96    12          7.76       1
# 97    10          7.78       0
# 98    12          5.63       1
# 99    10          6.61       0
#
# [100 rows x 3 columns]

# %%
df.count()
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
df.max()
# Out:
# cgpa            13.00
# resume_score     9.06
# placed           1.00
# dtype: float64

# %%
df.min()
# Out:
# cgpa            9.00
# resume_score    4.95
# placed          0.00
# dtype: float64

# %%
df.mean()
# Out:
# cgpa            10.4700
# resume_score     6.9305
# placed           0.5000
# dtype: float64

# %%
df["cgpa"].mean()
# Out:
# 10.47

# %%
df.median()
# Out:
# cgpa            10.000
# resume_score     7.055
# placed           0.500
# dtype: float64

# %%
df["cgpa"].median()
# Out:
# 10.0

# %%
filter_df = df.filter(items = ["cgpa", "placed"])
filter_df
# Out:
#     cgpa  placed
# 0     12       1
# 1     10       0
# 2     12       1
# 3     10       1
# 4     11       1
# ..   ...     ...
# 95    10       0
# 96    12       1
# 97    10       0
# 98    12       1
# 99    10       0
#
# [100 rows x 2 columns]

# %%
df[["cgpa","resume_score"]]
# Out:
#     cgpa  resume_score
# 0     12          6.52
# 1     10          5.17
# 2     12          8.86
# 3     10          7.27
# 4     11          7.30
# ..   ...           ...
# 95    10          6.38
# 96    12          7.76
# 97    10          7.78
# 98    12          5.63
# 99    10          6.61
#
# [100 rows x 2 columns]

# %%
# axis = 0, means row
df.filter(items = [3,4,2,5,6,2], axis = 0)
# Out:
#    cgpa  resume_score  placed
# 3    10          7.27       1
# 4    11          7.30       1
# 2    12          8.86       1
# 5    12          6.19       1
# 6     9          7.09       0

# %%
new_df = df.rename(columns = {"cgpa" : "updated_cgpa", "resume_score" : "updated_score"})
new_df
# Out:
#     updated_cgpa  updated_score  placed
# 0             12           6.52       1
# 1             10           5.17       0
# 2             12           8.86       1
# 3             10           7.27       1
# 4             11           7.30       1
# ..           ...            ...     ...
# 95            10           6.38       0
# 96            12           7.76       1
# 97            10           7.78       0
# 98            12           5.63       1
# 99            10           6.61       0
#
# [100 rows x 3 columns]

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0     12          6.52       1
# 1     10          5.17       0
# 2     12          8.86       1
# 3     10          7.27       1
# 4     11          7.30       1
# ..   ...           ...     ...
# 95    10          6.38       0
# 96    12          7.76       1
# 97    10          7.78       0
# 98    12          5.63       1
# 99    10          6.61       0
#
# [100 rows x 3 columns]

# %%
df["half"] = df["cgpa"].where(df["cgpa"]>7, other=0)
df
# Out:
#     cgpa  resume_score  placed  half
# 0     12          6.52       1    12
# 1     10          5.17       0    10
# 2     12          8.86       1    12
# 3     10          7.27       1    10
# 4     11          7.30       1    11
# ..   ...           ...     ...   ...
# 95    10          6.38       0    10
# 96    12          7.76       1    12
# 97    10          7.78       0    10
# 98    12          5.63       1    12
# 99    10          6.61       0    10
#
# [100 rows x 4 columns]
